# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from tqdm import tqdm

# %%
res = requests.get("https://quotes.toscrape.com/")
soup = BeautifulSoup(res.text,"html.parser")

# %%
data = []

for sp in soup.find_all("div",class_="quote"):
    quote = sp.find("span",class_="text").text[1:-1]
    author_name = sp.find("small").text
    author_id = sp.find("a").get("href")
    
    tags=[]
    for tag in sp.find_all("a",class_="tag"):
        tags.append(tag.text)
    tags = ",".join(tags)
    
    data.append([quote,author_name,author_id,tags])

# %%
data
# Out:
# [['The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.',
#   'Albert Einstein',
#   '/author/Albert-Einstein',
#   'change,deep-thoughts,thinking,world'],
#  ['It is our choices, Harry, that show what we truly are, far more than our abilities.',
#   'J.K. Rowling',
#   '/author/J-K-Rowling',
#   'abilities,choices'],
#  ['There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.',
#   'Albert Einstein',
#   '/author/Albert-Einstein',
#   'inspirational,life,live,miracle,miracles'],
#  ['The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.',
#   'Jane Austen',
#   '/author/Jane-Austen',
#   'aliteracy,books,classic,humor'],
#  ["Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.",
#   'Marilyn Monroe',
#   '/author/Marilyn-Monroe',
# ...

# %%
df = pd.read_csv("df.csv")

# %%
for i in df.values:
    df["author_link"] = ("http://quotes.toscrape.com/"+i[2])
df
# Out:
#                                                Quote        Author_name  \
# 0  The world as we have created it is a process o...    Albert Einstein
# 1  It is our choices, Harry, that show what we tr...       J.K. Rowling
# 2  There are only two ways to live your life. One...    Albert Einstein
# 3  The person, be it gentleman or lady, who has n...        Jane Austen
# 4  Imperfection is beauty, madness is genius and ...     Marilyn Monroe
# 5  Try not to become a man of success. Rather bec...    Albert Einstein
# 6  It is better to be hated for what you are than...         André Gide
# 7  I have not failed. I've just found 10,000 ways...   Thomas A. Edison
# 8  A woman is like a tea bag; you never know how ...  Eleanor Roosevelt
# 9   A day without sunshine is like, you know, night.       Steve Martin
#
#                    Author_id                                      tags  \
# 0    /author/Albert-Einstein       change,deep-thoughts,thinking,world
# ...

# %% [markdown]
# ## If we need to get authors data and save it into file

# %%
data = df

# %%
data
# Out:
#                                                Quote        Author_name  \
# 0  The world as we have created it is a process o...    Albert Einstein
# 1  It is our choices, Harry, that show what we tr...       J.K. Rowling
# 2  There are only two ways to live your life. One...    Albert Einstein
# 3  The person, be it gentleman or lady, who has n...        Jane Austen
# 4  Imperfection is beauty, madness is genius and ...     Marilyn Monroe
# 5  Try not to become a man of success. Rather bec...    Albert Einstein
# 6  It is better to be hated for what you are than...         André Gide
# 7  I have not failed. I've just found 10,000 ways...   Thomas A. Edison
# 8  A woman is like a tea bag; you never know how ...  Eleanor Roosevelt
# 9   A day without sunshine is like, you know, night.       Steve Martin
#
#                    Author_id                                      tags  \
# 0    /author/Albert-Einstein       change,deep-thoughts,thinking,world
# ...

# %%
del data["Quote"]
del data["Author_id"]
del data["tags"]

# %%
data
# Out:
#          Author_name                                      author_link
# 0    Albert Einstein  http://quotes.toscrape.com//author/Steve-Martin
# 1       J.K. Rowling  http://quotes.toscrape.com//author/Steve-Martin
# 2    Albert Einstein  http://quotes.toscrape.com//author/Steve-Martin
# 3        Jane Austen  http://quotes.toscrape.com//author/Steve-Martin
# 4     Marilyn Monroe  http://quotes.toscrape.com//author/Steve-Martin
# 5    Albert Einstein  http://quotes.toscrape.com//author/Steve-Martin
# 6         André Gide  http://quotes.toscrape.com//author/Steve-Martin
# 7   Thomas A. Edison  http://quotes.toscrape.com//author/Steve-Martin
# 8  Eleanor Roosevelt  http://quotes.toscrape.com//author/Steve-Martin
# 9       Steve Martin  http://quotes.toscrape.com//author/Steve-Martin

# %%
len(data.drop_duplicates())
# Out:
# 8

# %%
for i in data.values:
    name = "authors/" + i[0] + ".txt"
    link = i[1]
    res = requests.get(link)
    soup = BeautifulSoup(res.text,"html.parser")
    
    text = soup.find("div",class_ = "author_details").text
# Out:
# Albert Einstein http://quotes.toscrape.com//author/Steve-Martin
# J.K. Rowling http://quotes.toscrape.com//author/Steve-Martin
# Albert Einstein http://quotes.toscrape.com//author/Steve-Martin
# Jane Austen http://quotes.toscrape.com//author/Steve-Martin
# Marilyn Monroe http://quotes.toscrape.com//author/Steve-Martin
# Albert Einstein http://quotes.toscrape.com//author/Steve-Martin
# André Gide http://quotes.toscrape.com//author/Steve-Martin
# Thomas A. Edison http://quotes.toscrape.com//author/Steve-Martin
# Eleanor Roosevelt http://quotes.toscrape.com//author/Steve-Martin
# Steve Martin http://quotes.toscrape.com//author/Steve-Martin

# %%
df = pd.read_csv("df.csv")
df.head()
# Out:
#                                                Quote      Author_name  \
# 0  The world as we have created it is a process o...  Albert Einstein
# 1  It is our choices, Harry, that show what we tr...     J.K. Rowling
# 2  There are only two ways to live your life. One...  Albert Einstein
# 3  The person, be it gentleman or lady, who has n...      Jane Austen
# 4  Imperfection is beauty, madness is genius and ...   Marilyn Monroe
#
#                  Author_id                                      tags
# 0  /author/Albert-Einstein       change,deep-thoughts,thinking,world
# 1      /author/J-K-Rowling                         abilities,choices
# 2  /author/Albert-Einstein  inspirational,life,live,miracle,miracles
# 3      /author/Jane-Austen             aliteracy,books,classic,humor
# 4   /author/Marilyn-Monroe                 be-yourself,inspirational

# %%
for i in df.values:
    df["author_link"] = "http://quotes.toscrape.com/" + i[2]

# %%
df
# Out:
#                                                Quote        Author_name  \
# 0  The world as we have created it is a process o...    Albert Einstein
# 1  It is our choices, Harry, that show what we tr...       J.K. Rowling
# 2  There are only two ways to live your life. One...    Albert Einstein
# 3  The person, be it gentleman or lady, who has n...        Jane Austen
# 4  Imperfection is beauty, madness is genius and ...     Marilyn Monroe
# 5  Try not to become a man of success. Rather bec...    Albert Einstein
# 6  It is better to be hated for what you are than...         André Gide
# 7  I have not failed. I've just found 10,000 ways...   Thomas A. Edison
# 8  A woman is like a tea bag; you never know how ...  Eleanor Roosevelt
# 9   A day without sunshine is like, you know, night.       Steve Martin
#
#                    Author_id                                      tags  \
# 0    /author/Albert-Einstein       change,deep-thoughts,thinking,world
# ...

# %%
del df["Author_id"]
del df["Quote"]
del df["tags"]

# %%
df.values
# Out:
# array([['Albert Einstein',
#         'http://quotes.toscrape.com//author/Steve-Martin'],
#        ['J.K. Rowling',
#         'http://quotes.toscrape.com//author/Steve-Martin'],
#        ['Albert Einstein',
#         'http://quotes.toscrape.com//author/Steve-Martin'],
#        ['Jane Austen', 'http://quotes.toscrape.com//author/Steve-Martin'],
#        ['Marilyn Monroe',
#         'http://quotes.toscrape.com//author/Steve-Martin'],
#        ['Albert Einstein',
#         'http://quotes.toscrape.com//author/Steve-Martin'],
#        ['André Gide', 'http://quotes.toscrape.com//author/Steve-Martin'],
#        ['Thomas A. Edison',
#         'http://quotes.toscrape.com//author/Steve-Martin'],
#        ['Eleanor Roosevelt',
#         'http://quotes.toscrape.com//author/Steve-Martin'],
#        ['Steve Martin',
#         'http://quotes.toscrape.com//author/Steve-Martin']], dtype=object)

# %%
author_info = []
paths = []

for author in (df.values):
    name = 'Authors/' + df[0] + '.txt'
    link = author[1]
    
    res = requests.get(link)
    soup = BeautifulSoup(res.text,'html.parser')
    
    text = soup.find('div',class_ = 'author-details').text
    
    author_info.append(text.strip())
    paths.append(name)
    
    fd = open(name,'w')
    fd.write(text)
    fd.close()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
